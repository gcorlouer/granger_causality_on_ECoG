# %%
# %run  src/input_config.py

# %%
args.result_path
# Out:
# PosixPath('results')

# %%
# %run scripts/prepare_condition_specific_ts.py
# Out:
# Opening raw data file data/derivatives/AnRa/ieeg/AnRa_bad_chans_removed_raw.fif...
#     Range : 0 ... 348287 =      0.000 ...   696.574 secs
# Ready.
# Reading 0 ... 348287  =      0.000 ...   696.574 secs...
# Not setting metadata
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 200 events and 1126 original time points ...
# 0 bad epochs dropped
# Opening raw data file data/derivatives/AnRa/ieeg/AnRa_bad_chans_removed_raw.fif...
#     Range : 0 ... 348287 =      0.000 ...   696.574 secs
# Ready.
# Reading 0 ... 348287  =      0.000 ...   696.574 secs...
# Used Annotations descriptions: ['-1', '-2', 'Face010', 'Face020', 'Face030', 'Face040', 'Face050', 'Face060', 'Face070', 'Face110', 'Face120', 'Face130', 'Face140', 'Face150', 'Face160', 'Face170', 'Place010', 'Place020', 'Place030', 'Place040', 'Place050', 'Place060', 'Place070', 'Place110', 'Place120', 'Place130', 'Place140', 'Place150', 'Place160', 'Place170', 'boundary']
# Not setting metadata
# Not setting metadata
# 124 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 124 events and 1126 original time points ...
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:72: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)
# 4 bad epochs dropped
# Opening raw data file data/derivatives/AnRa/ieeg/AnRa_bad_chans_removed_raw.fif...
#     Range : 0 ... 348287 =      0.000 ...   696.574 secs
# Ready.
# Reading 0 ... 348287  =      0.000 ...   696.574 secs...
# Used Annotations descriptions: ['-1', '-2', 'Face010', 'Face020', 'Face030', 'Face040', 'Face050', 'Face060', 'Face070', 'Face110', 'Face120', 'Face130', 'Face140', 'Face150', 'Face160', 'Face170', 'Place010', 'Place020', 'Place030', 'Place040', 'Place050', 'Place060', 'Place070', 'Place110', 'Place120', 'Place130', 'Place140', 'Place150', 'Place160', 'Place170', 'boundary']
# Not setting metadata
# Not setting metadata
# 124 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 124 events and 1126 original time points ...
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:72: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)
# 4 bad epochs dropped
# Opening raw data file data/derivatives/AnRa/ieeg/AnRa_bad_chans_removed_raw.fif...
#     Range : 0 ... 348287 =      0.000 ...   696.574 secs
# Ready.
# Reading 0 ... 348287  =      0.000 ...   696.574 secs...
# Used Annotations descriptions: ['-1', '-2', 'Face010', 'Face020', 'Face030', 'Face040', 'Face050', 'Face060', 'Face070', 'Face110', 'Face120', 'Face130', 'Face140', 'Face150', 'Face160', 'Face170', 'Place010', 'Place020', 'Place030', 'Place040', 'Place050', 'Place060', 'Place070', 'Place110', 'Place120', 'Place130', 'Place140', 'Place150', 'Place160', 'Place170', 'boundary']
# Not setting metadata
# Not setting metadata
# 124 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 124 events and 1126 original time points ...
# 4 bad epochs dropped
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:72: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:57: RuntimeWarning: tmin is not in epochs time interval. tmin is set to epochs.tmin
#   epoch = epoch.copy().crop(tmin = -0.5, tmax=0)
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:58: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)
# Adapt indexing to matlab format
# Opening raw data file data/derivatives/ArLa/ieeg/ArLa_bad_chans_removed_raw.fif...
#     Range : 0 ... 348214 =      0.000 ...   696.428 secs
# Ready.
# Reading 0 ... 348214  =      0.000 ...   696.428 secs...
# Not setting metadata
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 200 events and 1126 original time points ...
# 0 bad epochs dropped
# Opening raw data file data/derivatives/ArLa/ieeg/ArLa_bad_chans_removed_raw.fif...
#     Range : 0 ... 348214 =      0.000 ...   696.428 secs
# Ready.
# Reading 0 ... 348214  =      0.000 ...   696.428 secs...
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:72: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)
# Used Annotations descriptions: ['-1', '-2', 'Face010', 'Face020', 'Face030', 'Face040', 'Face050', 'Face060', 'Face070', 'Face110', 'Face120', 'Face130', 'Face140', 'Face150', 'Face160', 'Face170', 'Place010', 'Place020', 'Place030', 'Place040', 'Place050', 'Place060', 'Place070', 'Place110', 'Place120', 'Place130', 'Place140', 'Place150', 'Place160', 'Place170', 'boundary']
# Not setting metadata
# Not setting metadata
# 124 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 124 events and 1126 original time points ...
# 4 bad epochs dropped
# Opening raw data file data/derivatives/ArLa/ieeg/ArLa_bad_chans_removed_raw.fif...
#     Range : 0 ... 348214 =      0.000 ...   696.428 secs
# Ready.
# Reading 0 ... 348214  =      0.000 ...   696.428 secs...
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:72: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)
# Used Annotations descriptions: ['-1', '-2', 'Face010', 'Face020', 'Face030', 'Face040', 'Face050', 'Face060', 'Face070', 'Face110', 'Face120', 'Face130', 'Face140', 'Face150', 'Face160', 'Face170', 'Place010', 'Place020', 'Place030', 'Place040', 'Place050', 'Place060', 'Place070', 'Place110', 'Place120', 'Place130', 'Place140', 'Place150', 'Place160', 'Place170', 'boundary']
# Not setting metadata
# Not setting metadata
# 124 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 124 events and 1126 original time points ...
# 4 bad epochs dropped
# Opening raw data file data/derivatives/ArLa/ieeg/ArLa_bad_chans_removed_raw.fif...
#     Range : 0 ... 348214 =      0.000 ...   696.428 secs
# Ready.
# Reading 0 ... 348214  =      0.000 ...   696.428 secs...
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:72: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)
# Used Annotations descriptions: ['-1', '-2', 'Face010', 'Face020', 'Face030', 'Face040', 'Face050', 'Face060', 'Face070', 'Face110', 'Face120', 'Face130', 'Face140', 'Face150', 'Face160', 'Face170', 'Place010', 'Place020', 'Place030', 'Place040', 'Place050', 'Place060', 'Place070', 'Place110', 'Place120', 'Place130', 'Place140', 'Place150', 'Place160', 'Place170', 'boundary']
# Not setting metadata
# Not setting metadata
# 124 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 124 events and 1126 original time points ...
# 4 bad epochs dropped
# Adapt indexing to matlab format
# Opening raw data file data/derivatives/DiAs/ieeg/DiAs_bad_chans_removed_raw.fif...
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:58: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)
#     Range : 0 ... 348212 =      0.000 ...   696.424 secs
# Ready.
# Reading 0 ... 348212  =      0.000 ...   696.424 secs...
# Not setting metadata
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 200 events and 1126 original time points ...
# 0 bad epochs dropped
# Opening raw data file data/derivatives/DiAs/ieeg/DiAs_bad_chans_removed_raw.fif...
#     Range : 0 ... 348212 =      0.000 ...   696.424 secs
# Ready.
# Reading 0 ... 348212  =      0.000 ...   696.424 secs...
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:72: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)
# Used Annotations descriptions: ['-1', '-2', 'Face010', 'Face020', 'Face030', 'Face040', 'Face050', 'Face060', 'Face070', 'Face110', 'Face120', 'Face130', 'Face140', 'Face150', 'Face160', 'Face170', 'Place010', 'Place020', 'Place030', 'Place040', 'Place050', 'Place060', 'Place070', 'Place110', 'Place120', 'Place130', 'Place140', 'Place150', 'Place160', 'Place170', 'boundary']
# Not setting metadata
# Not setting metadata
# 124 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 124 events and 1126 original time points ...
# 4 bad epochs dropped
# Opening raw data file data/derivatives/DiAs/ieeg/DiAs_bad_chans_removed_raw.fif...
#     Range : 0 ... 348212 =      0.000 ...   696.424 secs
# Ready.
# Reading 0 ... 348212  =      0.000 ...   696.424 secs...
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:72: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)
# Used Annotations descriptions: ['-1', '-2', 'Face010', 'Face020', 'Face030', 'Face040', 'Face050', 'Face060', 'Face070', 'Face110', 'Face120', 'Face130', 'Face140', 'Face150', 'Face160', 'Face170', 'Place010', 'Place020', 'Place030', 'Place040', 'Place050', 'Place060', 'Place070', 'Place110', 'Place120', 'Place130', 'Place140', 'Place150', 'Place160', 'Place170', 'boundary']
# Not setting metadata
# Not setting metadata
# 124 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 124 events and 1126 original time points ...
# 4 bad epochs dropped
# Opening raw data file data/derivatives/DiAs/ieeg/DiAs_bad_chans_removed_raw.fif...
#     Range : 0 ... 348212 =      0.000 ...   696.424 secs
# Ready.
# Reading 0 ... 348212  =      0.000 ...   696.424 secs...
# Used Annotations descriptions: ['-1', '-2', 'Face010', 'Face020', 'Face030', 'Face040', 'Face050', 'Face060', 'Face070', 'Face110', 'Face120', 'Face130', 'Face140', 'Face150', 'Face160', 'Face170', 'Place010', 'Place020', 'Place030', 'Place040', 'Place050', 'Place060', 'Place070', 'Place110', 'Place120', 'Place130', 'Place140', 'Place150', 'Place160', 'Place170', 'boundary']
# Not setting metadata
# Not setting metadata
# 124 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 124 events and 1126 original time points ...
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:72: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)
# 4 bad epochs dropped
# Adapt indexing to matlab format
#
#  Sampling frequency is 250.0Hz
#
#
#  Stimulus is during 0 and 1.5s
# /home/guime/projects/cifar/scripts/prepare_condition_specific_ts.py:58: RuntimeWarning: The measurement information indicates a low-pass frequency of 250 Hz. The decim=2 parameter will result in a sampling frequency of 250 Hz, which can cause aliasing artifacts.
#   epoch = epoch.copy().decimate(args.decim)

# %%
# Copy past in jupyter terminal to run matlab script
# run('scripts/compare_condition_gc.m')
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# Plot results
# %run plot_scripts/plot_compare_null_against_gc.py
# Out:
#  Sampling frequency is 250.0Hz
#
#
#  Stimulus is during 0 and 1.5s
# /home/guime/projects/cifar/src/plotting_lib.py:500: RuntimeWarning: invalid value encountered in true_divide
#   f = f/baseline
